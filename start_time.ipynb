# %%
# --- 0. Imports ---
from helpers.strategy_helper import *

# %% [markdown]
# # Distance Based Race Strategy
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
# --- 1. Core Inputs ---

# Race Information
race_distance = 6                     # total race time
lap_time_avg = 120.0              # seconds

# Car Information
tank_capacity = 75.0              # litres

fuel_per_lap = 2.6                # litres

pit_delta = 30.0                  # seconds (pit lane loss, not including fuel time)
refuelling_rate = 2.0             # litres per second
tyre_change_time = 15.0           # seconds
laps_per_stint_override = None    # set if you want fixed stint lengths


race_seconds = race_hours * 3600

# %%
laps_per_stint = stint_laps(fuel_per_lap, tank_capacity, lap_time_avg, laps_per_stint_override)

print("Laps per stint:", laps_per_stint)

# %%
# --- 4. Compare Strategies ---

results = []

for num_stops in range(1, 6):  # try 1–5 stops
    total_time_no_tyre = strategy_time(
        num_stops,
        laps_per_stint,
        lap_time_avg,
        pit_fn_no_tyres
    )
    total_time_tyre = strategy_time(
        num_stops,
        laps_per_stint,
        lap_time_avg,
        pit_fn_with_tyres
    )
    results.append((num_stops, total_time_no_tyre, total_time_tyre))

results
